# %%
#ASSISTmentsChall len 300
# !python main.py --data ASSISTmentsChall --max_len 300
# Out:
# Epoch: 1, train loss : 1097948.77
# --------------------
# Epoch: 2, train loss : 1026.292
# --------------------
# Epoch: 3, train loss : 935.155
# --------------------
# Epoch: 4, train loss : 902.056
# --------------------
# Epoch: 5, train loss : 877.27
# --------------------
# Epoch: 6, train loss : 851.378
# --------------------
# Epoch: 7, train loss : 857.254
# --------------------
# Epoch: 8, train loss : 868.405
# --------------------
# Epoch: 9, train loss : 836.009
# --------------------
# Epoch: 10, train loss : 817.386
# --------------------
# Epoch: 11, train loss : 793.713
# --------------------
# Epoch: 12, train loss : 798.663
# --------------------
# ^C
# Traceback (most recent call last):
#   File "/Users/sungsiklee/Desktop/Coding/P-VAE/main.py", line 128, in <module>
#     optimizer.step()
#   File "/Users/sungsiklee/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py", line 69, in wrapper
#     return wrapped(*args, **kwargs)
# ...

# %%
#ASSISTments0910 len 20
# !python main.py --data ASSISTments0910 --max_len 20
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Library/Python/3.10/lib/python/site-packages/IPython/utils/_process_posix.py:148, in ProcessHandler.system(self, cmd)
#     147 else:
# --> 148     child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     149 flush = sys.stdout.flush
#
# File ~/Library/Python/3.10/lib/python/site-packages/pexpect/pty_spawn.py:205, in spawn.__init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204 else:
# --> 205     self._spawn(command, args, preexec_fn, dimensions)
#     206 self.use_poll = use_poll
#
# File ~/Library/Python/3.10/lib/python/site-packages/pexpect/pty_spawn.py:303, in spawn._spawn(self, command, args, preexec_fn, dimensions)
# ...

# %%
#ASSISTments0910 len 50
# !python main.py --data ASSISTments0910 --max_len 50
# Out:
# Epoch: 1, train loss : 126.576
# --------------------
# Epoch: 2, train loss : 99.193
# --------------------
# Epoch: 3, train loss : 98.326
# --------------------
# Epoch: 4, train loss : 90.776
# --------------------
# Epoch: 5, train loss : 88.355
# --------------------
# Epoch: 6, train loss : 86.812
# --------------------
# Epoch: 7, train loss : 80.132
# --------------------
# Epoch: 8, train loss : 78.383
# --------------------
# Epoch: 9, train loss : 75.946
# --------------------
# Epoch: 10, train loss : 73.075
# --------------------
# Epoch: 11, train loss : 72.484
# --------------------
# Epoch: 12, train loss : 69.67
# --------------------
# Epoch: 13, train loss : 70.442
# --------------------
# Epoch: 14, train loss : 65.508
# --------------------
# Epoch: 15, train loss : 64.521
# --------------------
# Epoch: 16, train loss : 65.778
# --------------------
# Epoch: 17, train loss : 65.783
# --------------------
# Epoch: 18, train loss : 64.214
# --------------------
# ...

# %%
#ASSISTments2015 len 20
# !python main.py --data ASSISTments2015 --max_len 20
# Out:
# Epoch: 1, train loss : 48.546
# --------------------
# Epoch: 2, train loss : 46.552
# --------------------
# Epoch: 3, train loss : 44.826
# --------------------
# Epoch: 4, train loss : 42.901
# --------------------
# Epoch: 5, train loss : 40.737
# --------------------
# Epoch: 6, train loss : 39.388
# --------------------
# Epoch: 7, train loss : 38.064
# --------------------
# Epoch: 8, train loss : 37.339
# --------------------
# Epoch: 9, train loss : 36.03
# --------------------
# Epoch: 10, train loss : 35.218
# --------------------
# Epoch: 11, train loss : 34.149
# --------------------
# Epoch: 12, train loss : 33.907
# --------------------
# Epoch: 13, train loss : 33.243
# --------------------
# Epoch: 14, train loss : 33.064
# --------------------
# Epoch: 15, train loss : 32.4
# --------------------
# Epoch: 16, train loss : 31.886
# --------------------
# Epoch: 17, train loss : 32.035
# --------------------
# Epoch: 18, train loss : 31.558
# --------------------
# ...

# %%
#ASSISTments2015 len 50
# !python main.py --data ASSISTments2015 --max_len 50
# Out:
# Epoch: 1, train loss : 126.05
# --------------------
# Epoch: 2, train loss : 118.684
# --------------------
# Epoch: 3, train loss : 117.19
# --------------------
# Epoch: 4, train loss : 111.891
# --------------------
# Epoch: 5, train loss : 109.149
# --------------------
# Epoch: 6, train loss : 103.562
# --------------------
# Epoch: 7, train loss : 102.457
# --------------------
# Epoch: 8, train loss : 97.565
# --------------------
# Epoch: 9, train loss : 97.588
# --------------------
# Epoch: 10, train loss : 95.522
# --------------------
# Epoch: 11, train loss : 92.809
# --------------------
# Epoch: 12, train loss : 92.487
# --------------------
# Epoch: 13, train loss : 90.953
# --------------------
# Epoch: 14, train loss : 91.806
# --------------------
# Epoch: 15, train loss : 89.413
# --------------------
# Epoch: 16, train loss : 87.713
# --------------------
# Epoch: 17, train loss : 87.929
# --------------------
# Epoch: 18, train loss : 87.825
# ...

# %%
#STATIC len 200
# !python main.py --data STATIC --max_len 200
# Out:
# 35301.87s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Epoch: 1, train loss : 632.201
# --------------------
# Epoch: 2, train loss : 431.968
# --------------------
# Epoch: 3, train loss : 326.84
# --------------------
# Epoch: 4, train loss : 285.644
# --------------------
# Epoch: 5, train loss : 282.149
# --------------------
# Epoch: 6, train loss : 272.631
# --------------------
# Epoch: 7, train loss : 268.173
# --------------------
# Epoch: 8, train loss : 270.278
# --------------------
# Epoch: 9, train loss : 284.96
# --------------------
# Epoch: 10, train loss : 255.265
# --------------------
# Epoch: 11, train loss : 265.322
# --------------------
# Epoch: 12, train loss : 239.064
# --------------------
# Epoch: 13, train loss : 257.774
# --------------------
# Epoch: 14, train loss : 265.361
# --------------------
# Epoch: 15, train loss : 253.172
# --------------------
# Epoch: 16, train loss : 261.829
# --------------------
# ...

# %%
#STATIC len 300
# !python main.py --data STATIC --max_len 300
# Out:
# 47461.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Epoch: 1, train loss : 1271.603
# --------------------
# Epoch: 2, train loss : 626.36
# --------------------
# Epoch: 3, train loss : 476.982
# --------------------
# Epoch: 4, train loss : 433.526
# --------------------
# Epoch: 5, train loss : 446.237
# --------------------
# Epoch: 6, train loss : 437.622
# --------------------
# Epoch: 7, train loss : 436.652
# --------------------
# Epoch: 8, train loss : 407.538
# --------------------
# Epoch: 9, train loss : 433.893
# --------------------
# Epoch: 10, train loss : 418.347
# --------------------
# Epoch: 11, train loss : 429.121
# --------------------
# Epoch: 12, train loss : 397.857
# --------------------
# Epoch: 13, train loss : 418.507
# --------------------
# Epoch: 14, train loss : 414.514
# --------------------
# Epoch: 15, train loss : 414.769
# --------------------
# Epoch: 16, train loss : 412.378
# ...

# %%
#ASSISTmentsChall len 200
# !python main.py --data ASSISTmentsChall --max_len 200
# Out:
# 36006.77s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Epoch: 1, train loss : 749.439
# --------------------
# Epoch: 2, train loss : 442.891
# --------------------
# Epoch: 3, train loss : 443.455
# --------------------
# Epoch: 4, train loss : 413.342
# --------------------
# Epoch: 5, train loss : 417.715
# --------------------
# Epoch: 6, train loss : 415.565
# --------------------
# Epoch: 7, train loss : 395.052
# --------------------
# Epoch: 8, train loss : 397.035
# --------------------
# Epoch: 9, train loss : 393.876
# --------------------
# Epoch: 10, train loss : 382.521
# --------------------
# Epoch: 11, train loss : 390.061
# --------------------
# Epoch: 12, train loss : 383.025
# --------------------
# Epoch: 13, train loss : 373.635
# --------------------
# Epoch: 14, train loss : 389.278
# --------------------
# Epoch: 15, train loss : 379.745
# --------------------
# Epoch: 16, train loss : 364.65
# --------------------
# ...

# %%
#ASSISTmentsChall len 300
# !python main.py --data ASSISTmentsChall --max_len 300
# Out:
# 49195.43s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Epoch: 1, train loss : 27883.204
# --------------------
# Epoch: 2, train loss : 703.128
# --------------------
# Epoch: 3, train loss : 666.935
# --------------------
# Epoch: 4, train loss : 635.218
# --------------------
# Epoch: 5, train loss : 646.401
# --------------------
# Epoch: 6, train loss : 609.593
# --------------------
# Epoch: 7, train loss : 600.178
# --------------------
# Epoch: 8, train loss : 600.418
# --------------------
# Epoch: 9, train loss : 594.492
# --------------------
# Epoch: 10, train loss : 595.094
# --------------------
# Epoch: 11, train loss : 587.635
# --------------------
# Epoch: 12, train loss : 578.731
# --------------------
# Epoch: 13, train loss : 555.369
# --------------------
# Epoch: 14, train loss : 566.261
# --------------------
# Epoch: 15, train loss : 574.44
# --------------------
# Epoch: 16, train loss : 559.481
# ...
